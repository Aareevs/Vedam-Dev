# %% [markdown]
# # Pandas Revision
#
# Syntax on `placement.csv`, practice on `food_orders.csv`.

# %%
import pandas as pd

df = pd.read_csv('/Users/aareev/VS-Code/Vedam/Vedam Semester 3/Python(ML) Sem 3/Data/placement.csv')      # syntax examples
food = pd.read_csv('/Users/aareev/VS-Code/Vedam/Vedam Semester 3/Python(ML) Sem 3/Data/food_orders.csv')  # practice

# %% [markdown]
# ---
# ## 1. First look

# %%
# size: (rows, columns)
df.shape
# Out:
# (550, 12)

# %%
# numeric summary: count, mean, min, max
df.describe().round(2)
# Out:
#          cgpa  twelfth_percent  internships  projects  backlogs  prep_hours  \
# count  550.00           550.00       519.00    550.00    550.00      454.00
# mean     7.36            77.60         1.30      2.56      0.68      153.15
# std      0.98            10.12         1.18      1.49      1.10       86.06
# min      5.00            55.00         0.00      0.00      0.00       16.00
# 25%      6.69            70.90         0.00      1.00      0.00       90.00
# 50%      7.40            77.90         1.00      2.00      0.00      134.00
# 75%      7.98            84.50         2.00      4.00      1.00      192.75
# max     10.00            98.00         4.00      6.00      4.00      500.00
#
#        communication_score  package_lpa
# count               538.00       517.00
# mean                  6.27         4.71
# std                   1.69         3.48
# min                   1.10         0.00
# 25%                   5.20         0.00
# 50%                   6.30         6.01
# 75%                   7.40         7.28
# max                  10.00        12.56

# %%
# column types and non-null counts
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 550 entries, 0 to 549
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   student_id           550 non-null    str
#  1   cgpa                 550 non-null    float64
#  2   twelfth_percent      550 non-null    float64
#  3   branch               550 non-null    str
#  4   internships          519 non-null    float64
#  5   projects             550 non-null    int64
#  6   backlogs             550 non-null    int64
#  7   prep_hours           454 non-null    float64
#  8   communication_score  538 non-null    float64
#  9   hostel               550 non-null    str
#  10  placed               550 non-null    str
#  11  package_lpa          517 non-null    float64
# dtypes: float64(6), int64(2), str(4)
# memory usage: 51.7 KB

# %% [markdown]
# ### Practice

# %% [markdown]
# **Q1.** How many orders are in the file, and how many details are stored for each order?

# %%
food.shape
# Out:
# (612, 13)

# %% [markdown]
# **Q2.** Someone ordered food worth a small EMI. Find the biggest order value and the longest delivery time using one command.

# %%
food[['order_value', 'delivery_time_min']].max()
# Out:
# order_value          2354
# delivery_time_min      63
# dtype: int64

# %% [markdown]
# **Q3.** Which columns hold numbers and which hold text?

# %%
food.dtypes
# Out:
# order_id                 str
# city                     str
# cuisine                  str
# day                      str
# order_hour             int64
# quantity               int64
# distance_km          float64
# order_value            int64
# delivery_time_min      int64
# payment                  str
# rating               float64
# tip                  float64
# was_late                 str
# dtype: object

# %% [markdown]
# ---
# ## 2. Selecting

# %%
# one column
df['cgpa']
# Out:
# 0      7.41
# 1      7.52
# 2      7.35
# 3      7.86
# 4      5.63
#        ...
# 545    8.40
# 546    7.60
# 547    6.33
# 548    8.86
# 549    8.45
# Name: cgpa, Length: 550, dtype: float64

# %%
# many columns: a list inside [ ]
df[['branch', 'cgpa', 'placed']].head()
# Out:
#   branch  cgpa placed
# 0     IT  7.41     No
# 1    CSE  7.52    Yes
# 2    CSE  7.35    Yes
# 3    CSE  7.86    Yes
# 4    CSE  5.63    Yes

# %%
# iloc: by position -> rows, columns
df.iloc[0:5, 0:3]
# Out:
#   student_id  cgpa  twelfth_percent
# 0     VS2821  7.41             78.5
# 1     VS3068  7.52             70.0
# 2     VS2940  7.35             78.3
# 3     VS3138  7.86             60.2
# 4     VS2670  5.63             88.3

# %%
# loc: by label -> rows, column names (both ends included)
df.loc[0:4, 'cgpa':'internships']
# Out:
#    cgpa  twelfth_percent branch  internships
# 0  7.41             78.5     IT          0.0
# 1  7.52             70.0    CSE          2.0
# 2  7.35             78.3    CSE          2.0
# 3  7.86             60.2    CSE          1.0
# 4  5.63             88.3    CSE          2.0

# %% [markdown]
# ### Practice

# %% [markdown]
# **Q4.** The manager's eyes hurt after 13 columns. Show only `city`, `cuisine` and `order_value` for the first 10 orders.

# %%
food[['city', 'cuisine', 'order_value']].head(10)
# Out:
#         city       cuisine  order_value
# 0     Mumbai       Chinese          519
# 1       Pune       Chinese          295
# 2  Hyderabad       Chinese          744
# 3      Delhi      Desserts          370
# 4      Delhi        Burger          594
# 5     Mumbai       Biryani          933
# 6  Hyderabad  South Indian          197
# 7       Pune       Biryani         1482
# 8  Bangalore       Biryani          522
# 9       Pune  South Indian          233

# %% [markdown]
# **Q5.** The printer jammed and printed only rows 50 to 54, first 5 columns. Recreate that page using positions.

# %%
food.iloc[50:55, 0:5]
# Out:
#     order_id       city       cuisine  day  order_hour
# 50  ORD10161  Bangalore         Pizza  Sun          22
# 51  ORD10156       Pune      Desserts  Mon          21
# 52  ORD10160      Delhi      Desserts  Sat          20
# 53  ORD10310       Pune      Desserts  Sun          13
# 54  ORD10018     Mumbai  South Indian  Sat          18

# %% [markdown]
# **Q6.** Using labels, show rows 100 to 105 and every column from `city` to `order_hour`.

# %%
food.loc[100:105, 'city':'order_hour']
# Out:
#           city       cuisine  day  order_hour
# 100       Pune       Biryani  Sat          12
# 101       Pune        Burger  Sun          21
# 102     Mumbai         Pizza  Thu          17
# 103  Bangalore       Biryani  Sun          19
# 104     Mumbai         Pizza  Sun          23
# 105     Mumbai  South Indian  Sun          13

# %% [markdown]
# ---
# ## 3. Filtering and sorting

# %%
# one condition
df[df['cgpa'] > 8]
# Out:
#     student_id  cgpa  twelfth_percent branch  internships  projects  backlogs  \
# 14      VS2701  9.01             64.8    ECE          1.0         0         1
# 16      VS3012  8.29             77.8    CSE          0.0         2         0
# 17      VS2892  8.84             86.3  Civil          1.0         2         0
# 18      VS2936  8.23             69.5    CSE          3.0         3         1
# 21      VS2930  8.07             83.1   Mech          1.0         2         0
# ..         ...   ...              ...    ...          ...       ...       ...
# 537     VS2668  8.21             74.2    CSE          0.0         4         0
# 539     VS2966  8.45             80.9   Mech          2.0         2         1
# 545     VS2811  8.40             79.7    ECE          1.0         4         0
# 548     VS2796  8.86             78.2    ECE          3.0         1         0
# 549     VS2775  8.45             70.7    CSE          0.0         3         0
#
#      prep_hours  communication_score hostel placed  package_lpa
# 14          NaN                  4.8    Yes    Yes         6.70
# 16         81.0                  7.9    Yes    Yes         8.06
# 17        132.0                  3.4     No    Yes         5.77
# 18        119.0                  6.9    Yes    Yes         8.54
# 21        120.0                  9.5    Yes    Yes         5.38
# ..          ...                  ...    ...    ...          ...
# 537       157.0                  5.5    Yes    Yes         7.66
# 539        90.0                  7.6     No    Yes         7.31
# 545       173.0                  5.0    Yes    Yes         6.22
# 548       259.0                  6.4    Yes    Yes         7.51
# 549         NaN                  5.1    Yes    Yes         8.45
#
# [135 rows x 12 columns]

# %%
# two conditions: & is and, | is or, each in its own ( )
df[(df['cgpa'] > 8) & (df['backlogs'] == 0)]
# Out:
#     student_id  cgpa  twelfth_percent branch  internships  projects  backlogs  \
# 16      VS3012  8.29             77.8    CSE          0.0         2         0
# 17      VS2892  8.84             86.3  Civil          1.0         2         0
# 21      VS2930  8.07             83.1   Mech          1.0         2         0
# 44      VS3139  8.85             81.2   Mech          0.0         3         0
# 47      VS2788  8.09             84.6   Mech          0.0         2         0
# ..         ...   ...              ...    ...          ...       ...       ...
# 534     VS3112  8.37             63.9    CSE          4.0         2         0
# 537     VS2668  8.21             74.2    CSE          0.0         4         0
# 545     VS2811  8.40             79.7    ECE          1.0         4         0
# 548     VS2796  8.86             78.2    ECE          3.0         1         0
# 549     VS2775  8.45             70.7    CSE          0.0         3         0
#
#      prep_hours  communication_score hostel placed  package_lpa
# 16         81.0                  7.9    Yes    Yes         8.06
# 17        132.0                  3.4     No    Yes         5.77
# 21        120.0                  9.5    Yes    Yes         5.38
# 44        194.0                  7.4     No    Yes         6.89
# 47        220.0                  6.0    Yes     No         0.00
# ..          ...                  ...    ...    ...          ...
# 534       103.0                  5.9    Yes    Yes         7.52
# 537       157.0                  5.5    Yes    Yes         7.66
# 545       173.0                  5.0    Yes    Yes         6.22
# 548       259.0                  6.4    Yes    Yes         7.51
# 549         NaN                  5.1    Yes    Yes         8.45
#
# [87 rows x 12 columns]

# %%
# value is one of many
df[df['branch'].isin(['CSE', 'IT'])]

# value inside a range (both ends included)
df[df['cgpa'].between(7, 8)]
# Out:
#     student_id  cgpa  twelfth_percent branch  internships  projects  backlogs  \
# 0       VS2821  7.41             78.5     IT          0.0         6         1
# 1       VS3068  7.52             70.0    CSE          2.0         3         0
# 2       VS2940  7.35             78.3    CSE          2.0         0         3
# 3       VS3138  7.86             60.2    CSE          1.0         3         0
# 6       VS2971  7.79             74.7    CSE          0.0         4         0
# ..         ...   ...              ...    ...          ...       ...       ...
# 536     VS3032  7.53             83.5    ECE          0.0         2         3
# 542     VS2998  7.81             63.4     IT          4.0         4         0
# 543     VS2785  7.19             77.5    ECE          3.0         4         0
# 544     VS2948  7.18             87.2    ECE          NaN         1         1
# 546     VS3102  7.60             76.5  Civil          0.0         4         0
#
#      prep_hours  communication_score hostel placed  package_lpa
# 0         188.0                  4.3     No     No         0.00
# 1         167.0                  9.8    Yes    Yes        10.06
# 2         199.0                  4.8    Yes    Yes          NaN
# 3         135.0                  8.0     No    Yes         8.63
# 6           NaN                  7.3    Yes     No         0.00
# ..          ...                  ...    ...    ...          ...
# 536        20.0                  6.7     No     No         0.00
# 542        89.0                  5.1    Yes    Yes         8.52
# 543        84.0                  6.5     No    Yes         6.68
# 544       296.0                  4.2    Yes     No         0.00
# 546         NaN                  6.7    Yes    Yes         5.68
#
# [227 rows x 12 columns]

# %%
# count of each category
df['branch'].value_counts()
# Out:
# branch
# CSE      167
# IT       118
# ECE      112
# Mech     103
# Civil     50
# Name: count, dtype: int64

# %%
# sort, biggest first
df.sort_values('cgpa', ascending=False).head()
# Out:
#     student_id   cgpa  twelfth_percent branch  internships  projects  \
# 113     VS3148  10.00             93.9   Mech          3.0         3
# 500     VS2917  10.00             84.0    ECE          0.0         4
# 265     VS2702   9.95             86.5    CSE          2.0         0
# 185     VS3124   9.85             63.8    CSE          0.0         4
# 157     VS2747   9.78             85.3    ECE          2.0         2
#
#      backlogs  prep_hours  communication_score hostel placed  package_lpa
# 113         0       190.0                  6.8    Yes    Yes         9.17
# 500         0        58.0                  6.3     No    Yes         8.54
# 265         0       248.0                  7.0     No    Yes        10.03
# 185         0        87.0                  7.5    Yes    Yes         8.77
# 157         0         NaN                  5.3    Yes    Yes          NaN

# %% [markdown]
# ### Practice

# %% [markdown]
# **Q7.** Biryani at 2 AM is not hunger, it is a lifestyle. Count the Biryani orders placed between midnight and 3 AM (hours 0 to 3).

# %%
food[(food['cuisine'] == 'Biryani') & (food['order_hour'].between(0, 3))].shape[0]
# Out:
# 35

# %% [markdown]
# **Q8.** Someone in Pune is clearly throwing a party. Show Pune orders worth more than 1000 rupees. How many?

# %%
pune_orders = food[(food['city'] == 'Pune') & (food['order_value'] > 1000)]

print(pune_orders)
print("Count:", pune_orders.shape[0])
# Out:
#      order_id  city       cuisine  day  order_hour  quantity  distance_km  \
# 7    ORD10171  Pune       Biryani  Sun          23         5          4.2
# 16   ORD10099  Pune       Biryani  Sat          21         6          2.2
# 48   ORD10343  Pune       Chinese  Sat          14         5          5.3
# 90   ORD10466  Pune         Pizza  Sun          20         6          6.4
# 113  ORD10147  Pune       Chinese  Sun          19         8         11.4
# 137  ORD10460  Pune         Pizza  Fri          12         5          6.0
# 180  ORD10469  Pune         Pizza  Mon          16         4          4.0
# 192  ORD10253  Pune         Pizza  Thu          22         6          2.5
# 203  ORD10428  Pune  South Indian  Mon          19         8          4.1
# 225  ORD10411  Pune         Pizza  Sat           1         4          8.2
# 226  ORD10168  Pune       Biryani  Sun          12         5          2.0
# 228  ORD10362  Pune       Biryani  Fri          21         4          4.6
# 332  ORD10405  Pune       Biryani  Sat          13         4          7.7
# 335  ORD10465  Pune       Biryani  Sat          18         4          2.1
# 358  ORD10594  Pune       Biryani  Mon           2         4          6.6
# 367  ORD10303  Pune       Biryani  Thu          20         8          3.9
# 387  ORD10207  Pune         Pizza  Sat          16         5          2.4
# 423  ORD10154  Pune       Biryani  Wed          12         5          4.3
# 429  ORD10596  Pune       Chinese  Sat          21         8          0.6
# 483  ORD10085  Pune       Chinese  Fri          19         5          2.7
# 504  ORD10466  Pune         Pizza  Sun          20         6          6.4
# 574  ORD10246  Pune       Biryani  Sun          19         5          3.5
# 607  ORD10126  Pune       Chinese  Sat          21         8          4.4
#
#      order_value  delivery_time_min payment  rating   tip was_late
# 7           1482                 28    Cash     5.0  25.0       No
# 16          1310                 20    Card     3.0   NaN       No
# 48          1164                 31     UPI     5.0   NaN       No
# 90          1659                 31     UPI     5.0  40.0       No
# 113         1845                 56     UPI     NaN   NaN      Yes
# 137         1461                 32     UPI     5.0  25.0       No
# 180         1017                 28     UPI     3.0  45.0       No
# 192         1108                 27    Cash     NaN   NaN       No
# 203         1014                 30     UPI     4.0  20.0       No
# 225         1013                 36    Card     5.0  20.0       No
# 226         1573                 26    Card     NaN  30.0       No
# 228         1061                 24     UPI     NaN  35.0       No
# 332         1178                 38     UPI     3.0  20.0       No
# 335         1255                 30     UPI     5.0  45.0       No
# 358         1150                 28     UPI     5.0  20.0       No
# 367         1944                 23    Card     4.0  40.0       No
# 387         1383                 28     UPI     5.0  30.0       No
# 423         1261                 18    Card     5.0  30.0       No
# 429         1437                 21     UPI     NaN  25.0       No
# 483         1011                 28     UPI     5.0  25.0       No
# 504         1659                 31     UPI     5.0  40.0       No
# 574         1464                 31     UPI     5.0  45.0       No
# 607         1518                 21     UPI     NaN  30.0       No
# Count: 23

# %% [markdown]
# **Q9.** A food blogger survives only on Pizza and Burger. How many such orders are there?

# %%
food[food['cuisine'].isin(['Pizza', 'Burger'])].shape[0]
# Out:
# 190

# %% [markdown]
# **Q10.** How many deliveries fell in the *"bhaiya, kahan ho?"* zone of 30 to 45 minutes?

# %%
food[food['delivery_time_min'].between(30, 45)].shape[0]
# Out:
# 222

# %% [markdown]
# **Q11.** Does anyone still pay in cash? Count the orders by payment method.

# %%
food['payment'].value_counts()
# Out:
# payment
# UPI     363
# Card    154
# Cash     95
# Name: count, dtype: int64

# %% [markdown]
# **Q12.** Someone definitely ordered for the whole hostel. Show the 5 biggest orders with `city`, `cuisine`, `quantity` and `order_value`.

# %%
food.sort_values('order_value', ascending=False)[
    ['city', 'cuisine', 'quantity', 'order_value']
].head(5)
# Out:
#           city  cuisine  quantity  order_value
# 586  Hyderabad  Biryani         8         2354
# 544  Hyderabad  Biryani         8         2254
# 476     Mumbai  Biryani         8         2114
# 367       Pune  Biryani         8         1944
# 388  Hyderabad  Biryani         6         1895

# %% [markdown]
# **Q13.** Which delivery partners were basically The Flash? Show the 5 fastest deliveries with `city`, `distance_km` and `delivery_time_min`.

# %%
food.sort_values('delivery_time_min')[
    ['city', 'distance_km', 'delivery_time_min']
].head(5)
# Out:
#           city  distance_km  delivery_time_min
# 325       Pune          1.2                  8
# 580       Pune          1.4                  8
# 480      Delhi          1.0                  8
# 121  Hyderabad          1.3                  8
# 458      Delhi          1.4                  9

# %% [markdown]
# ---
# ## 4. Cleaning

# %%
# blanks per column
df.isnull().sum()
# Out:
# student_id              0
# cgpa                    0
# twelfth_percent         0
# branch                  0
# internships            31
# projects                0
# backlogs                0
# prep_hours             96
# communication_score    12
# hostel                  0
# placed                  0
# package_lpa            33
# dtype: int64

# %%
# repeated rows
print(df.duplicated().sum())

# remove repeated rows
df_clean = df.drop_duplicates()
# Out:
# 0

# %%
# remove rows where one column is blank
df_clean = df_clean.dropna(subset=['internships'])

# fill blanks with a value
df_clean['prep_hours'] = df_clean['prep_hours'].fillna(0)

# change the type
df_clean['internships'] = df_clean['internships'].astype(int)

# %%
# new column from existing columns
df_clean['cgpa_percent'] = (df_clean['cgpa'] * 9.5).round(1)
df_clean[['cgpa', 'cgpa_percent']].head()
# Out:
#    cgpa  cgpa_percent
# 0  7.41          70.4
# 1  7.52          71.4
# 2  7.35          69.8
# 3  7.86          74.7
# 4  5.63          53.5

# %% [markdown]
# ### Practice

# %% [markdown]
# **Q14.** Count the blanks in every column.

# %%
food.isnull().sum()
# Out:
# order_id               0
# city                   0
# cuisine                0
# day                    0
# order_hour             0
# quantity               0
# distance_km            8
# order_value            0
# delivery_time_min      0
# payment                0
# rating               107
# tip                  185
# was_late               0
# dtype: int64

# %% [markdown]
# **Q15.** The app got confused and saved some orders twice. How many repeated rows are there?

# %%
food.duplicated().sum()
# Out:
# np.int64(12)

# %% [markdown]
# **Q16.** Remove the repeated orders before customers get charged twice. Print the shape.

# %%
food_clean = food.drop_duplicates()

print(food_clean.shape)
# Out:
# (600, 13)

# %% [markdown]
# **Q17.** GPS failed for some orders, so the delivery partner took the scenic route. Remove the rows with a blank `distance_km` and print the shape.

# %%
food_clean = food_clean.dropna(
    subset=['distance_km']
)

print(food_clean.shape)
# Out:
# (593, 13)

# %% [markdown]
# **Q18.** A blank tip means no tip, and one sad delivery partner. Fill the blanks in `tip` with 0 and make it a whole number.

# %%
food_clean['tip'] = food_clean['tip'].fillna(0).astype(int)

print(food_clean['tip'].isnull().sum())
print(food_clean['tip'].dtype)
# Out:
# 0
# int64

# %% [markdown]
# **Q19.** Add a column `value_per_item`: order value divided by quantity, rounded.

# %%
food_clean['value_per_item'] = (
    food_clean['order_value'] /
    food_clean['quantity']
).round()

food_clean[
    ['order_value', 'quantity', 'value_per_item']
].head()
# Out:
#    order_value  quantity  value_per_item
# 0          519         3           173.0
# 1          295         1           295.0
# 2          744         3           248.0
# 3          370         3           123.0
# 4          594         4           148.0

# %% [markdown]
# ---
# ## 5. Grouping and saving

# %%
# average per group
df.groupby('branch')['cgpa'].mean()
# Out:
# branch
# CSE      7.484431
# Civil    7.341200
# ECE      7.377054
# IT       7.183051
# Mech     7.342233
# Name: cgpa, dtype: float64

# %%
# sorted, highest first
df.groupby('branch')['cgpa'].mean().sort_values(ascending=False)
# Out:
# branch
# CSE      7.484431
# ECE      7.377054
# Mech     7.342233
# Civil    7.341200
# IT       7.183051
# Name: cgpa, dtype: float64

# %%
# other numbers per group
df.groupby('branch')['cgpa'].max()
df.groupby('branch')['internships'].sum()
df.groupby('branch')['student_id'].count()
# Out:
# branch
# CSE      167
# Civil     50
# ECE      112
# IT       118
# Mech     103
# Name: student_id, dtype: int64

# %%
# save to a file, without the index column
df_clean.to_csv('placement_clean.csv', index=False)

# %% [markdown]
# ### Practice

# %% [markdown]
# **Q20.** Which city is the stingiest tipper? Find the average tip per city, lowest first.

# %%
food_clean.groupby('city')['tip'].mean().sort_values()
# Out:
# city
# Delhi        12.575758
# Hyderabad    16.363636
# Pune         20.354610
# Mumbai       23.089431
# Bangalore    29.694656
# Name: tip, dtype: float64

# %% [markdown]
# **Q21.** Is the weekend really a party? Find the average order value for each day, highest first.

# %%
food_clean.groupby('day')['order_value'].mean().sort_values(
    ascending=False
)
# Out:
# day
# Sat    666.465753
# Sun    663.818182
# Fri    588.244444
# Tue    562.818182
# Mon    560.800000
# Wed    558.819672
# Thu    540.590909
# Name: order_value, dtype: float64

# %% [markdown]
# **Q22.** Does a late delivery earn an angry rating? Compare the average rating of late and on-time orders.

# %%
food_clean.groupby('was_late')['rating'].mean()
# Out:
# was_late
# No     4.168182
# Yes    3.104167
# Name: rating, dtype: float64

# %% [markdown]
# **Q23.** Which city holds the record for the single biggest order after cleaning? Find the highest order value in each city.

# %%
food_clean.groupby('city')['order_value'].max()
# Out:
# city
# Bangalore    1687
# Delhi        1618
# Hyderabad    2254
# Mumbai       2114
# Pune         1944
# Name: order_value, dtype: int64

# %% [markdown]
# **Q24.** Which payment method brings in the most money? Find the total order value for each payment method.

# %%
food_clean.groupby('payment')['order_value'].sum()
# Out:
# payment
# Card     93538
# Cash     56571
# UPI     211442
# Name: order_value, dtype: int64

# %% [markdown]
# **Q25.** Which cuisine is the nation's favourite? Count the orders for each cuisine.

# %%
food_clean['cuisine'].value_counts()
# Out:
# cuisine
# Biryani         138
# Pizza           111
# South Indian    105
# Chinese         100
# Burger           73
# Desserts         66
# Name: count, dtype: int64

# %% [markdown]
# **Q26.** Save the cleaned data as `food_orders_clean.csv` without the index column.

# %%
food_clean.to_csv(
    'food_orders_clean.csv',
    index=False
)

# %% [markdown]
# ---
# *Q16 to Q19 change `food`. Run them only once, in order.*
